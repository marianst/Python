# %% [markdown]
# # Conteúdo extra Matplotlib

# %% [markdown]
# ## Exemplo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as datetime

# %%
url1_vale = '/content/drive/MyDrive/Colab Notebooks/VALE3.SA.csv'

# %%
url2_usim = '/content/drive/MyDrive/Colab Notebooks/USIM5.SA.csv'

# %%
vale3 = pd.read_csv(url1_vale)

# %%
usim5 = pd.read_csv(url2_usim)

# %%
vale3.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  3.500000  3.542500  3.500000  3.500000   1.665134   585600.0
# 1  2000-01-04  3.466666  3.474166  3.416666  3.416666   1.625488   782400.0
# 2  2000-01-05  3.375000  3.416666  3.375000  3.416666   1.625488  1876800.0

# %%
usim5.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  2.177777  2.180000  2.122222  2.133333   1.509654   571500.0
# 1  2000-01-04  2.111111  2.111111  2.055555  2.055555   1.454614  1121400.0
# 2  2000-01-05  2.066666  2.255555  2.055555  2.251111   1.592999  1602450.0

# %%
vale3.tail(3)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 5887  2023-06-09  69.669998  69.800003  68.250000  68.360001  68.360001
# 5888  2023-06-12  67.800003  67.800003  66.699997  67.120003  67.120003
# 5889  2023-06-13        NaN        NaN        NaN        NaN        NaN
#
#           Volume
# 5887  30056800.0
# 5888  26651200.0
# 5889         NaN

# %%
usim5.tail(3)
# Out:
#             Date  Open  High   Low  Close  Adj Close      Volume
# 5886  2023-06-07  7.44  7.44  7.29   7.34       7.34   9641600.0
# 5887  2023-06-09  7.39  7.45  7.30   7.33       7.33  12946200.0
# 5888  2023-06-12   NaN   NaN   NaN    NaN        NaN         NaN

# %%
vale3.Date = pd.to_datetime(vale3.Date)

# %%
usim5.Date = pd.to_datetime(usim5.Date)

# %% [markdown]
# Função Concat

# %%
pd.concat([vale3, usim5])
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 0    2000-01-03  3.500000  3.542500  3.500000  3.500000   1.665134    585600.0
# 1    2000-01-04  3.466666  3.474166  3.416666  3.416666   1.625488    782400.0
# 2    2000-01-05  3.375000  3.416666  3.375000  3.416666   1.625488   1876800.0
# 3    2000-01-06  3.416666  3.500000  3.416666  3.416666   1.625488    792000.0
# 4    2000-01-07  3.458333  3.559166  3.458333  3.541666   1.684958   5347200.0
# ...         ...       ...       ...       ...       ...        ...         ...
# 5884 2023-06-05  7.420000  7.460000  7.290000  7.410000   7.410000   5639600.0
# 5885 2023-06-06  7.410000  7.480000  7.380000  7.390000   7.390000  14242400.0
# 5886 2023-06-07  7.440000  7.440000  7.290000  7.340000   7.340000   9641600.0
# 5887 2023-06-09  7.390000  7.450000  7.300000  7.330000   7.330000  12946200.0
# 5888 2023-06-12       NaN       NaN       NaN       NaN        NaN         NaN
#
# [11779 rows x 7 columns]

# %%
teste = pd.concat([vale3, usim5], ignore_index=True)

# %%
teste
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     2000-01-03  3.500000  3.542500  3.500000  3.500000   1.665134
# 1     2000-01-04  3.466666  3.474166  3.416666  3.416666   1.625488
# 2     2000-01-05  3.375000  3.416666  3.375000  3.416666   1.625488
# 3     2000-01-06  3.416666  3.500000  3.416666  3.416666   1.625488
# 4     2000-01-07  3.458333  3.559166  3.458333  3.541666   1.684958
# ...          ...       ...       ...       ...       ...        ...
# 11774 2023-06-05  7.420000  7.460000  7.290000  7.410000   7.410000
# 11775 2023-06-06  7.410000  7.480000  7.380000  7.390000   7.390000
# 11776 2023-06-07  7.440000  7.440000  7.290000  7.340000   7.340000
# 11777 2023-06-09  7.390000  7.450000  7.300000  7.330000   7.330000
# 11778 2023-06-12       NaN       NaN       NaN       NaN        NaN
#
#            Volume
# 0        585600.0
# 1        782400.0
# 2       1876800.0
# 3        792000.0
# 4       5347200.0
# ...           ...
# 11774   5639600.0
# 11775  14242400.0
# 11776   9641600.0
# 11777  12946200.0
# 11778         NaN
#
# [11779 rows x 7 columns]

# %% [markdown]
# Função Merge

# %%
pd.merge(vale3, usim5, on = "Date")
# Out:
#            Date     Open_x     High_x      Low_x    Close_x  Adj Close_x  \
# 0    2000-01-03   3.500000   3.542500   3.500000   3.500000     1.665134
# 1    2000-01-04   3.466666   3.474166   3.416666   3.416666     1.625488
# 2    2000-01-05   3.375000   3.416666   3.375000   3.416666     1.625488
# 3    2000-01-06   3.416666   3.500000   3.416666   3.416666     1.625488
# 4    2000-01-07   3.458333   3.559166   3.458333   3.541666     1.684958
# ...         ...        ...        ...        ...        ...          ...
# 5884 2023-06-05  68.470001  68.480003  66.629997  67.379997    67.379997
# 5885 2023-06-06  67.800003  68.389999  67.400002  67.599998    67.599998
# 5886 2023-06-07  67.599998  68.680000  67.400002  68.669998    68.669998
# 5887 2023-06-09  69.669998  69.800003  68.250000  68.360001    68.360001
# 5888 2023-06-12  67.800003  67.800003  66.699997  67.120003    67.120003
#
#         Volume_x    Open_y    High_y     Low_y   Close_y  Adj Close_y  \
# 0       585600.0  2.177777  2.180000  2.122222  2.133333     1.509654
# 1       782400.0  2.111111  2.111111  2.055555  2.055555     1.454614
# 2      1876800.0  2.066666  2.255555  2.055555  2.251111     1.592999
# 3       792000.0  2.222222  2.455555  2.222222  2.455555     1.737674
# 4      5347200.0  2.455555  2.577777  2.444444  2.553333     1.806867
# ...          ...       ...       ...       ...       ...          ...
# 5884  21478500.0  7.420000  7.460000  7.290000  7.410000     7.410000
# 5885  31884200.0  7.410000  7.480000  7.380000  7.390000     7.390000
# 5886  27377500.0  7.440000  7.440000  7.290000  7.340000     7.340000
# 5887  30056800.0  7.390000  7.450000  7.300000  7.330000     7.330000
# 5888  26651200.0       NaN       NaN       NaN       NaN          NaN
#
#         Volume_y
# 0       571500.0
# 1      1121400.0
# 2      1602450.0
# 3      3084300.0
# 4      2871000.0
# ...          ...
# 5884   5639600.0
# 5885  14242400.0
# 5886   9641600.0
# 5887  12946200.0
# 5888         NaN
#
# [5889 rows x 13 columns]

# %%
df_juntos = pd.merge(vale3, usim5, on = "Date")

# %%
df_juntos.columns
# Out:
# Index(['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Adj Close_x',
#        'Volume_x', 'Open_y', 'High_y', 'Low_y', 'Close_y', 'Adj Close_y',
#        'Volume_y'],
#       dtype='object')

# %%
df_juntos.columns = ['Date', 'Open_vale', 'High_vale', 'Low_vale', 'Close_vale', 'Adj Close_vale',
       'Volume_vale', 'Open_usim', 'High_usim', 'Low_usim', 'Close_usim', 'Adj Close_usim',
       'Volume_usim']

# %%
fig1 = plt.figure(figsize=(15,8))
eixo1 = fig1.add_axes([0,0,2,1])

eixo1.plot(df_juntos.Date, df_juntos.Close_vale, color='green')
eixo1.plot(df_juntos.Date, df_juntos.Close_usim, color='black')

# %% [markdown]
# Calculo e grafico da variação.

# %%
df_juntos.head()
# Out:
#         Date  Open_vale  High_vale  Low_vale  Close_vale  Adj Close_vale  \
# 0 2000-01-03   3.500000   3.542500  3.500000    3.500000        1.665134
# 1 2000-01-04   3.466666   3.474166  3.416666    3.416666        1.625488
# 2 2000-01-05   3.375000   3.416666  3.375000    3.416666        1.625488
# 3 2000-01-06   3.416666   3.500000  3.416666    3.416666        1.625488
# 4 2000-01-07   3.458333   3.559166  3.458333    3.541666        1.684958
#
#    Volume_vale  Open_usim  High_usim  Low_usim  Close_usim  Adj Close_usim  \
# 0     585600.0   2.177777   2.180000  2.122222    2.133333        1.509654
# 1     782400.0   2.111111   2.111111  2.055555    2.055555        1.454614
# 2    1876800.0   2.066666   2.255555  2.055555    2.251111        1.592999
# 3     792000.0   2.222222   2.455555  2.222222    2.455555        1.737674
# 4    5347200.0   2.455555   2.577777  2.444444    2.553333        1.806867
#
#    Volume_usim
# 0     571500.0
# 1    1121400.0
# 2    1602450.0
# 3    3084300.0
# 4    2871000.0

# %%
df_juntos['var%_vale']= df_juntos['Close_vale'].div(3.5)-1

# %%
df_juntos['var%_usim']= df_juntos['Close_usim'].div(2.133333)-1

# %%
df_juntos
# Out:
#            Date  Open_vale  High_vale   Low_vale  Close_vale  Adj Close_vale  \
# 0    2000-01-03   3.500000   3.542500   3.500000    3.500000        1.665134
# 1    2000-01-04   3.466666   3.474166   3.416666    3.416666        1.625488
# 2    2000-01-05   3.375000   3.416666   3.375000    3.416666        1.625488
# 3    2000-01-06   3.416666   3.500000   3.416666    3.416666        1.625488
# 4    2000-01-07   3.458333   3.559166   3.458333    3.541666        1.684958
# ...         ...        ...        ...        ...         ...             ...
# 5884 2023-06-05  68.470001  68.480003  66.629997   67.379997       67.379997
# 5885 2023-06-06  67.800003  68.389999  67.400002   67.599998       67.599998
# 5886 2023-06-07  67.599998  68.680000  67.400002   68.669998       68.669998
# 5887 2023-06-09  69.669998  69.800003  68.250000   68.360001       68.360001
# 5888 2023-06-12  67.800003  67.800003  66.699997   67.120003       67.120003
#
#       Volume_vale  Open_usim  High_usim  Low_usim  Close_usim  Adj Close_usim  \
# 0        585600.0   2.177777   2.180000  2.122222    2.133333        1.509654
# 1        782400.0   2.111111   2.111111  2.055555    2.055555        1.454614
# 2       1876800.0   2.066666   2.255555  2.055555    2.251111        1.592999
# 3        792000.0   2.222222   2.455555  2.222222    2.455555        1.737674
# 4       5347200.0   2.455555   2.577777  2.444444    2.553333        1.806867
# ...           ...        ...        ...       ...         ...             ...
# 5884   21478500.0   7.420000   7.460000  7.290000    7.410000        7.410000
# 5885   31884200.0   7.410000   7.480000  7.380000    7.390000        7.390000
# 5886   27377500.0   7.440000   7.440000  7.290000    7.340000        7.340000
# 5887   30056800.0   7.390000   7.450000  7.300000    7.330000        7.330000
# 5888   26651200.0        NaN        NaN       NaN         NaN             NaN
#
#       Volume_usim  var%_vale  var%_usim
# 0        571500.0   0.000000   0.000000
# 1       1121400.0  -0.023810  -0.036458
# 2       1602450.0  -0.023810   0.055208
# 3       3084300.0  -0.023810   0.151042
# 4       2871000.0   0.011905   0.196875
# ...           ...        ...        ...
# 5884    5639600.0  18.251428   2.473438
# 5885   14242400.0  18.314285   2.464063
# 5886    9641600.0  18.619999   2.440626
# 5887   12946200.0  18.531429   2.435938
# 5888          NaN  18.177144        NaN
#
# [5889 rows x 15 columns]

# %%
fig1 = plt.figure(figsize=(15,8))
eixo1 = fig1.add_axes([0,0,2,1])

eixo1.plot(df_juntos.Date, df_juntos['var%_vale'], color='green')
eixo1.plot(df_juntos.Date, df_juntos['var%_usim'], color='black')

# %%
fig2, eixo2 = plt.subplots(2,2, figsize=(20,5))



eixo2[0,0].plot(df_juntos.Date, df_juntos.Close_vale, color='green')
eixo2[0,1].plot(df_juntos.Date, df_juntos.Close_usim, color='black')
eixo2[1,0].plot(df_juntos.Date, df_juntos.Open_usim, color='red')
eixo2[1,1].plot(df_juntos.Date, df_juntos.Open_vale, color='blue')

# %%
fig2, eixo2 = plt.subplots(1,2, figsize=(20,5), facecolor= '#0c5149')


eixo2[0].plot(df_juntos.Date, df_juntos.Close_vale, color='#07f9a2')
eixo2[0].set_title('Vale - VALE3', fontsize=50, pad=50, color='#07f9a2')
eixo2[0].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='#07f9a2')
eixo2[0].set_xlabel('Data', fontsize=30, labelpad=20, color='#07f9a2')
eixo2[0].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='#1c3e38')
eixo2[0].set_facecolor('#0d192b')
eixo2[1].plot(df_juntos.Date, df_juntos.Close_usim, color='#5bcebf')
eixo2[1].set_title('Usiminas - USIM5', fontsize=50, pad=50, color='#5bcebf')
eixo2[1].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='#5bcebf')
eixo2[1].set_xlabel('Data', fontsize=30, labelpad=20, color='#5bcebf')
eixo2[1].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='#1c3e38')
eixo2[1].set_facecolor('#0d192b')
plt.show()

# %% [markdown]
# Padronização do eixo Y

# %%
fig2, eixo2 = plt.subplots(1,2, figsize=(20,5), facecolor= '#0c5149')


eixo2[0].plot(df_juntos.Date, df_juntos.Close_vale, color='#07f9a2')
eixo2[0].set_title('Vale - VALE3', fontsize=50, pad=50, color='#07f9a2')
eixo2[0].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='#07f9a2')
eixo2[0].set_xlabel('Data', fontsize=30, labelpad=20, color='#07f9a2')
eixo2[0].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='#1c3e38')
eixo2[0].set_facecolor('#0d192b')
eixo2[0].set_ylim(0, 120)

eixo2[1].plot(df_juntos.Date, df_juntos.Close_usim, color='#5bcebf')
eixo2[1].set_title('Usiminas - USIM5', fontsize=50, pad=50, color='#5bcebf')
eixo2[1].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='#5bcebf')
eixo2[1].set_xlabel('Data', fontsize=30, labelpad=20, color='#5bcebf')
eixo2[1].set_ylim(0, 120)
eixo2[1].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='#1c3e38')
eixo2[1].set_facecolor('#0d192b')
plt.show()

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1) Colher os dados do mesmo período de duas empresas listadas na bolsa de valores que possuem o mesmo seguimento, e plotar um grafico de comparação entre as duas.

# %% [markdown]
# Importar Base

# %%
url_magalu = '/content/drive/MyDrive/Colab Notebooks/MGLU3.SA.csv'

# %%
url_americanas = '/content/drive/MyDrive/Colab Notebooks/AMER3.SA.csv'

# %%
magalu = pd.read_csv(url_magalu)

# %%
americanas = pd.read_csv(url_americanas)

# %%
magalu.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2011-05-02  4.705845  4.851989  4.705845  4.808146   4.428368  29936513
# 1  2011-05-03  4.822760  4.878295  4.735074  4.764303   4.387988   3599867
# 2  2011-05-04  4.770149  4.816915  4.770149  4.816915   4.436444   4191406
# 3  2011-05-05  4.796454  4.796454  4.770149  4.787686   4.409524   3752456
# 4  2011-05-06  4.778917  4.787686  4.676616  4.752611   4.377220   4134612

# %%
americanas.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2005-03-30  20.220636  20.220636  18.732536  18.925116  18.232233  6485275
# 1  2005-03-31  19.073925  19.073925  17.156902  18.925116  18.232233  4768251
# 2  2005-04-01  18.925116  19.257750  18.294861  18.382397  17.709385   812244
# 3  2005-04-04  17.944719  18.032255  16.684214  17.296961  16.663689   341462
# 4  2005-04-05  17.507044  17.507044  16.850531  17.043106  16.419127   423486

# %% [markdown]
# Mudar formato da coluna data.

# %%
magalu.Date = pd.to_datetime(magalu.Date)

# %%
americanas.Date = pd.to_datetime(americanas.Date)

# %% [markdown]
# Juntar as duas tabela

# %%
pd.merge(magalu, americanas, on = "Date")
# Out:
#            Date     Open_x     High_x      Low_x    Close_x  Adj Close_x  \
# 0    2011-05-02   4.705845   4.851989   4.705845   4.808146     4.428368
# 1    2011-05-03   4.822760   4.878295   4.735074   4.764303     4.387988
# 2    2011-05-04   4.770149   4.816915   4.770149   4.816915     4.436444
# 3    2011-05-05   4.796454   4.796454   4.770149   4.787686     4.409524
# 4    2011-05-06   4.778917   4.787686   4.676616   4.752611     4.377220
# ...         ...        ...        ...        ...        ...          ...
# 3269 2024-06-28  12.140000  12.200000  11.650000  12.050000    12.050000
# 3270 2024-07-01  12.020000  12.290000  11.880000  12.140000    12.140000
# 3271 2024-07-02  12.100000  12.330000  11.950000  12.170000    12.170000
# 3272 2024-07-03  12.260000  12.730000  12.260000  12.580000    12.580000
# 3273 2024-07-04  12.850000  13.460000  12.830000  13.180000    13.180000
#
#       Volume_x     Open_y     High_y      Low_y    Close_y  Adj Close_y  \
# 0     29936513  19.305756  19.394314  18.721268  19.084358    18.708580
# 1      3599867  18.951521  19.084358  18.623854  18.730124    18.361320
# 2      4191406  18.818684  19.261475  18.712414  18.898384    18.526268
# 3      3752456  18.756693  19.190628  18.694700  18.951521    18.578358
# 4      4134612  19.314610  20.589853  19.234907  20.457014    20.054207
# ...        ...        ...        ...        ...        ...          ...
# 3269  25687100   0.400000   0.400000   0.380000   0.390000     0.390000
# 3270  16498900   0.390000   0.410000   0.380000   0.400000     0.400000
# 3271  15119100   0.410000   0.410000   0.390000   0.390000     0.390000
# 3272  17333200   0.400000   0.420000   0.390000   0.390000     0.390000
# 3273  23480800   0.400000   0.420000   0.390000   0.400000     0.400000
#
#       Volume_y
# 0      1170751
# 1       486119
# 2       715459
# 3       453259
# 4      1707571
# ...        ...
# 3269  15319700
# 3270  15712600
# 3271  12145300
# 3272  17746600
# 3273  19877000
#
# [3274 rows x 13 columns]

# %%
magamer = pd.merge(magalu, americanas, on = "Date")

# %% [markdown]
# Trocar nome das colunas

# %%
magamer.columns
# Out:
# Index(['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Adj Close_x',
#        'Volume_x', 'Open_y', 'High_y', 'Low_y', 'Close_y', 'Adj Close_y',
#        'Volume_y'],
#       dtype='object')

# %%
magamer.columns = ['Date', 'Open_magalu', 'High_magalu', 'Low_magalu', 'Close_magalu', 'Adj Close_magalu',
       'Volume_magalu', 'Open_americanas', 'High_americanas', 'Low_americanas', 'Close_americanas', 'Adj Close_americanas',
       'Volume_americanas']

# %%
magamer.head()
# Out:
#         Date  Open_magalu  High_magalu  Low_magalu  Close_magalu  \
# 0 2011-05-02     4.705845     4.851989    4.705845      4.808146
# 1 2011-05-03     4.822760     4.878295    4.735074      4.764303
# 2 2011-05-04     4.770149     4.816915    4.770149      4.816915
# 3 2011-05-05     4.796454     4.796454    4.770149      4.787686
# 4 2011-05-06     4.778917     4.787686    4.676616      4.752611
#
#    Adj Close_magalu  Volume_magalu  Open_americanas  High_americanas  \
# 0          4.428368       29936513        19.305756        19.394314
# 1          4.387988        3599867        18.951521        19.084358
# 2          4.436444        4191406        18.818684        19.261475
# 3          4.409524        3752456        18.756693        19.190628
# 4          4.377220        4134612        19.314610        20.589853
#
#    Low_americanas  Close_americanas  Adj Close_americanas  Volume_americanas
# 0       18.721268         19.084358             18.708580            1170751
# 1       18.623854         18.730124             18.361320             486119
# 2       18.712414         18.898384             18.526268             715459
# 3       18.694700         18.951521             18.578358             453259
# 4       19.234907         20.457014             20.054207            1707571

# %% [markdown]
# Plotar o grafico

# %%
fig1 = plt.figure(figsize=(15,8))
eixo1 = fig1.add_axes([0,0,2,1])

eixo1.plot(magamer.Date, magamer.Close_magalu, color='blue')
eixo1.plot(magamer.Date, magamer.Close_americanas, color='red')

# %% [markdown]
# Extra (não era necessário fazer)

# %%
magamer['var%_magalu']= magamer['Close_magalu'].div(4.808146)-1
magamer['var%_americanas']= magamer['Close_americanas'].div(18.925116)-1

# %%
fig1 = plt.figure(figsize=(15,8))
eixo1 = fig1.add_axes([0,0,2,1])

eixo1.plot(magamer.Date, magamer['var%_magalu'], color='blue')
eixo1.plot(magamer.Date, magamer['var%_americanas'], color='red')

# %% [markdown]
# 2) Aplicar a função subplots e plotar os mesmos 2 gráficos separadamente.

# %%
fig2, eixo2 = plt.subplots(1,2, figsize=(20,5))


eixo2[0].plot(magamer.Date, magamer.Close_magalu, color='blue')
eixo2[0].set_title('Magalu - MGLU3', fontsize=50, pad=50, color='blue')
eixo2[0].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='blue')
eixo2[0].set_xlabel('Data', fontsize=30, labelpad=20, color='blue')
eixo2[0].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='black')
eixo2[0].set_facecolor('#0d192b')
eixo2[0].set_ylim(0, 280)

eixo2[1].plot(magamer.Date, magamer.Close_americanas, color='red')
eixo2[1].set_title('Americanas - AMER3', fontsize=50, pad=50, color='red')
eixo2[1].set_ylabel('Valor da Ação em R$', fontsize=30, labelpad=20, color='red')
eixo2[1].set_xlabel('Data', fontsize=30, labelpad=20, color='red')
eixo2[1].legend(['Valor da ação em R$'], loc='upper left' , fontsize=12, labelcolor='black')
eixo2[1].set_facecolor('#0d192b')
eixo2[1].set_ylim(0, 280)
plt.show()
