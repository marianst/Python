# %% [markdown]
# # Matplotlib

# %% [markdown]
# ##Exemplo

# %% [markdown]
# Analise do histórico de cotações das ações da empresa Usiminas através do gráfico de linha da biblioteca matplotlib.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Importar as bibliotecas e a base de dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = '/content/drive/MyDrive/Colab Notebooks/USIM5.SA.csv'

# %%
usim5 = pd.read_csv(url)

# %%
usim5.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  2.177777  2.180000  2.122222  2.133333   1.509654   571500.0
# 1  2000-01-04  2.111111  2.111111  2.055555  2.055555   1.454614  1121400.0
# 2  2000-01-05  2.066666  2.255555  2.055555  2.251111   1.592999  1602450.0
# 3  2000-01-06  2.222222  2.455555  2.222222  2.455555   1.737674  3084300.0
# 4  2000-01-07  2.455555  2.577777  2.444444  2.553333   1.806867  2871000.0

# %% [markdown]
# ###Verificar as informações da tabela e alterar o formato da coluna Date.

# %%
usim5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5889 entries, 0 to 5888
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5889 non-null   object
#  1   Open       5887 non-null   float64
#  2   High       5887 non-null   float64
#  3   Low        5887 non-null   float64
#  4   Close      5887 non-null   float64
#  5   Adj Close  5887 non-null   float64
#  6   Volume     5887 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 322.2+ KB

# %%
usim5.Date = pd.to_datetime(usim5.Date)

# %%
usim5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5889 entries, 0 to 5888
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5889 non-null   datetime64[ns]
#  1   Open       5887 non-null   float64
#  2   High       5887 non-null   float64
#  3   Low        5887 non-null   float64
#  4   Close      5887 non-null   float64
#  5   Adj Close  5887 non-null   float64
#  6   Volume     5887 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 322.2 KB

# %% [markdown]
# Criar a primeira figura.

# %%
figura1 = plt.figure(figsize=(15,8))

# %%
figura1 = plt.figure(figsize=(15,8))
plt.plot(usim5.Date, usim5.Close)

# %% [markdown]
# ### Alterando as dimensões da figura e do gráfico

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,3,1])
eixo1.plot(usim5.Date, usim5.Close)

# %% [markdown]
# ### Alterando Título do gráfico e dos eixos.

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close)
eixo1.set_title('Usiminas - USIM5')
eixo1.set_ylabel('Valor por ação em R$')
eixo1.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Alterando tamanho das fontes de título

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close)
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Adcionar legenda

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close)
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=20 )

# %% [markdown]
# ### Alterando as cores da linha
#
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)

# %% [markdown]
# Alterando o background

# %% [markdown]
# Dark

# %%
plt.style.use('dark_background')
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)

# %% [markdown]
# Classico

# %%
plt.style.use('classic')
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)

# %% [markdown]
# seaborn-darkgrid

# %%
plt.style.use('seaborn-darkgrid')
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
# Out:
# <ipython-input-21-abe88367c73c>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# Face color
#
# https://celke.com.br/artigo/tabela-de-cores-html-nome-hexadecimal-rgb

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
eixo1.set_facecolor('#000000')

# %% [markdown]
# Linhas de grade

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)

# %% [markdown]
# ###Intervalo de Data

# %%
from datetime import datetime
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)
eixo1.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
# Out:
# (16071.0, 16801.0)

# %% [markdown]
# ###Trabalhando com dois eixos.

# %% [markdown]
# Adicionando um novo eixo

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo2 = figura1.add_axes([1,0.5,0.8,0.3])


eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)


eixo2.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo2.set_title('2014 - 2016')
eixo2.set_xlabel('Data', fontsize=30)
eixo2.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
eixo2.set_facecolor('#5F9EA0')

# %% [markdown]
# Alterações na localização do novo eixo.

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo2 = figura1.add_axes([1.05,0.55,0.9,0.4])


eixo1.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper left', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)


eixo2.plot(usim5.Date, usim5.Close, color = 'springgreen')
eixo2.set_title('2014 - 2016', fontsize=20, color='white')
eixo2.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
eixo2.set_facecolor('#5F9EA0')

# %% [markdown]
# Enfase para a área do grafico menor.

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo2 = figura1.add_axes([1.05,0.55,0.9,0.4])

esquerda = usim5.Date < datetime(2014,1,1)
direita =  usim5.Date > datetime(2016,1,1)


eixo1.plot(usim5.Date, usim5.Close, color = 'red')
eixo1.plot(usim5[esquerda]['Date'], usim5[esquerda]['Close'], color = 'springgreen')
eixo1.plot(usim5[direita]['Date'], usim5[direita]['Close'], color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper left', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)


eixo2.plot(usim5.Date, usim5.Close, color = 'red')
eixo2.set_title('2014 - 2016', fontsize=20, color='white')
eixo2.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
eixo2.set_facecolor('#5F9EA0')

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo2 = figura1.add_axes([1.05,0.55,0.9,0.4])

esquerda = usim5.Date < datetime(2014,1,1)
direita =  usim5.Date > datetime(2016,1,1)

eixo1.plot(usim5.Date, usim5.Close, color = 'red')
eixo1.plot(usim5[esquerda]['Date'], usim5[esquerda]['Close'], color = 'springgreen')
eixo1.plot(usim5[direita]['Date'], usim5[direita]['Close'], color = 'springgreen')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper left', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)


eixo2.plot(usim5.Date, usim5.Close, color = 'red')
eixo2.set_title('2014 - 2016', fontsize=20, color='white')
eixo2.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
eixo2.set_facecolor('#5F9EA0')

# %% [markdown]
# Comparar duas linhas no mesmo gráfico

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])


eixo1.plot(usim5.Date, usim5.Close, color = '#e9e0d1')
eixo1.plot(usim5.Date, usim5.Open, color = '#000000')
eixo1.set_title('Usiminas - USIM5', fontsize=50, pad=30, color='#68462b')
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor de Fechamento ação em R$', 'Valor de abertura ação em R$'], loc='upper left', fontsize=30)
eixo1.set_xlim(datetime(2012,1,1), datetime(2013,3,1))
eixo1.set_facecolor('#33605a')
eixo1.grid(True)

# %% [markdown]
# Histograma para os valores de fechamento da ações

# %%
fig2 = plt.figure(figsize=(5,4))
eixo3 = fig2.add_axes([0,0,1,1])

eixo3.hist(usim5.Close, edgecolor = "#000000", color = '#60e9fd')
eixo3.set_title('Histograma do preço das ações USIM5')
eixo3.set_xlabel('Preço das ações em R$')
eixo3.set_ylabel('Frequência em Fechamentos')
eixo3.set_facecolor('#72adbb')

# %%
usim5.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2000-01-03  2.177777  2.180000  2.122222  2.133333   1.509654   571500.0
# 1 2000-01-04  2.111111  2.111111  2.055555  2.055555   1.454614  1121400.0
# 2 2000-01-05  2.066666  2.255555  2.055555  2.251111   1.592999  1602450.0
# 3 2000-01-06  2.222222  2.455555  2.222222  2.455555   1.737674  3084300.0
# 4 2000-01-07  2.455555  2.577777  2.444444  2.553333   1.806867  2871000.0

# %%
usim5[['Date','Volume']].groupby(pd.Grouper(key='Date', freq='y')).sum('Volume')
# Out:
#                   Volume
# Date
# 2000-12-31  4.345196e+08
# 2001-12-31  6.080751e+08
# 2002-12-31  7.000520e+08
# 2003-12-31  9.563530e+08
# 2004-12-31  1.145683e+09
# 2005-12-31  1.434786e+09
# 2006-12-31  3.169415e+10
# 2007-12-31  1.309026e+09
# 2008-12-31  1.273263e+09
# 2009-12-31  1.491743e+09
# 2010-12-31  1.707320e+09
# 2011-12-31  1.479643e+09
# 2012-12-31  1.880438e+09
# 2013-12-31  1.755169e+09
# 2014-12-31  1.742686e+09
# 2015-12-31  2.225830e+09
# 2016-12-31  6.436218e+09
# 2017-12-31  4.233431e+09
# 2018-12-31  3.735408e+09
# 2019-12-31  3.265533e+09
# 2020-12-31  5.295177e+09
# 2021-12-31  5.407140e+09
# 2022-12-31  4.959650e+09
# 2023-12-31  1.486805e+09

# %%
volume_por_ano = usim5[['Date','Volume']].groupby(pd.Grouper(key='Date', freq='y')).sum('Volume')

# %%
fig3 = plt.figure(figsize=(10,4))
eixo4 = fig3.add_axes([0,0,1,1])

eixo4.bar(volume_por_ano.index, volume_por_ano.Volume, width=300, edgecolor = "#71b584", color = '#599c6c')
eixo4.set_title('volume negociado por ano')
eixo4.set_ylabel('Preço das ações em TRI R$')
eixo4.set_xlabel('ANO')
eixo4.set_facecolor('#baffcb')

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1) Escolher uma empresa ou índice que tenha histórico de negociações na bolsa de valores, coletar os dados em csv na internet (Yahoo Finanças), importar a base de dados e criar um grafico de linha com o histórico das ações, e um grafico de enfase para o período da pandemia da covid-19.
#
#
#
#
# https://br.financas.yahoo.com/

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = '/content/drive/MyDrive/Colab Notebooks/MGLU3.SA.csv'

MGLU3 = pd.read_csv(url)

# %%
MGLU3.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2011-05-02  4.705845  4.851989  4.705845  4.808146   4.428368  29936513
# 1  2011-05-03  4.822760  4.878295  4.735074  4.764303   4.387988   3599867
# 2  2011-05-04  4.770149  4.816915  4.770149  4.816915   4.436444   4191406
# 3  2011-05-05  4.796454  4.796454  4.770149  4.787686   4.409524   3752456
# 4  2011-05-06  4.778917  4.787686  4.676616  4.752611   4.377220   4134612

# %%
MGLU3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3274 entries, 0 to 3273
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3274 non-null   object
#  1   Open       3274 non-null   float64
#  2   High       3274 non-null   float64
#  3   Low        3274 non-null   float64
#  4   Close      3274 non-null   float64
#  5   Adj Close  3274 non-null   float64
#  6   Volume     3274 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 179.2+ KB

# %%
MGLU3.Date = pd.to_datetime(MGLU3.Date)

# %%
MGLU3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3274 entries, 0 to 3273
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3274 non-null   datetime64[ns]
#  1   Open       3274 non-null   float64
#  2   High       3274 non-null   float64
#  3   Low        3274 non-null   float64
#  4   Close      3274 non-null   float64
#  5   Adj Close  3274 non-null   float64
#  6   Volume     3274 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 179.2 KB

# %%
figura1 = plt.figure(figsize=(10,10))
eixo1 = figura1.add_axes([0,0,2,1])
eixo1.plot(MGLU3.Date, MGLU3.Close, color = 'springgreen')
eixo1.set_title('Magalu - MGLU3', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper right', fontsize=30)
eixo1.set_facecolor('#000000')

eixo2.plot(MGLU3.Date, MGLU3.Close, color = 'springgreen')
eixo2.set_title('2014 - 2016')
eixo2.set_xlabel('Data', fontsize=30)
eixo2.set_xlim(datetime(2014,1,1), datetime(2016,1,1))
eixo2.set_facecolor('#5F9EA0')

# %%
figura1 = plt.figure(figsize=(10,10))
#eixo1 = figura1.add_axes([0,0,2,1])
#eixo2 = figura1.add_axes([1.05,0.55,0.9,0.4])

eixo1 = figura1.add_axes([0,0,2,1])
eixo2 = figura1.add_axes([0.3,0.5,0.8,0.3])

esquerda_covid = MGLU3.Date < datetime(2019,12,31)
direita_covid =  MGLU3.Date > datetime(2023,5,5)


eixo1.plot(MGLU3.Date, MGLU3.Close, color = 'red')
eixo1.plot(MGLU3[esquerda_covid]['Date'], MGLU3[esquerda_covid]['Close'], color = 'springgreen')
eixo1.plot(MGLU3[direita_covid]['Date'], MGLU3[direita_covid]['Close'], color = 'springgreen')
eixo1.set_title('Magalu - MGLU3', fontsize=50, pad=30)
eixo1.set_ylabel('Valor por ação em R$', fontsize=30)
eixo1.set_xlabel('Data', fontsize=30)
eixo1.legend(['Valor da ação em R$'], loc='upper left', fontsize=30)
eixo1.set_facecolor('#008080')
eixo1.grid(False)


eixo2.plot(MGLU3.Date, MGLU3.Close, color = 'red')
eixo2.set_title('Pandemia', fontsize=20, color='white')
eixo2.set_xlim(datetime(2019,12,31), datetime(2023,5,5))
eixo2.set_facecolor('#5F9EA0')

# %% [markdown]
# 2) Plotar um gráfico de barras com o valor médio de fechamento das ações, agrupado por ano.

# %%
MGLU3.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume
# 0 2011-05-02  4.705845  4.851989  4.705845  4.808146   4.428368  29936513
# 1 2011-05-03  4.822760  4.878295  4.735074  4.764303   4.387988   3599867
# 2 2011-05-04  4.770149  4.816915  4.770149  4.816915   4.436444   4191406
# 3 2011-05-05  4.796454  4.796454  4.770149  4.787686   4.409524   3752456
# 4 2011-05-06  4.778917  4.787686  4.676616  4.752611   4.377220   4134612

# %%
fechamento_por_ano = MGLU3[['Date','Close']].groupby(pd.Grouper(key='Date', freq='y')).mean('Close')

# %%
fig3 = plt.figure(figsize=(16,7))
eixo4 = fig3.add_axes([0,0,1,1])

eixo4.bar(fechamento_por_ano.index, fechamento_por_ano.Close, width=300, edgecolor = "#71b584", color = '#599c6c')
eixo4.set_title('Fechamento negociado por ano')
eixo4.set_ylabel('Preço das ações em TRI R$')
eixo4.set_xlabel('ANO')
eixo4.set_facecolor('#baffcb')

# %% [markdown]
# 3) plotar um histograma com o preço de fechamento das ações.

# %%
fig4 = plt.figure(figsize=(10,4))
eixo4 = fig4.add_axes([0,0,1,1])

eixo4.hist(MGLU3.Close)
# Out:
# (array([1948.,  559.,  196.,   99.,   94.,   65.,   45.,  120.,   89.,
#           59.]),
#  array([  0.286077 ,  25.9320939,  51.5781108,  77.2241277, 102.8701446,
#         128.5161615, 154.1621784, 179.8081953, 205.4542122, 231.1002291,
#         256.746246 ]),
#  <BarContainer object of 10 artists>)
